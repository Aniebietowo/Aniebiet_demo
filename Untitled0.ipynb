# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniebietowo/Aniebiet_demo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a6163fd9-7910-48c3-99f0-1f6e555d0b58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6163fd9-7910-48c3-99f0-1f6e555d0b58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("DataSet.csv")

# %%
print(df)
# Out:
#        Country Country Code                        Region  \
# 0        India          IND  Emerging and Developing Asia
# 1        India          IND  Emerging and Developing Asia
# 2        India          IND  Emerging and Developing Asia
# 3        India          IND  Emerging and Developing Asia
# 4        India          IND  Emerging and Developing Asia
# ..         ...          ...                           ...
# 95  Uzbekistan          UZB  Middle East and Central Asia
# 96  Uzbekistan          UZB  Middle East and Central Asia
# 97  Uzbekistan          UZB  Middle East and Central Asia
# 98  Uzbekistan          UZB  Middle East and Central Asia
# 99  Uzbekistan          UZB  Middle East and Central Asia
#
#                                               Element  \
# 0                                   Remittance inflow
# 1              Gross domestic product, current prices
# 2                                      Percent of GDP
# ...

# %%
df.head()
# Out:
#   Country Country Code                        Region  \
# 0   India          IND  Emerging and Developing Asia
# 1   India          IND  Emerging and Developing Asia
# 2   India          IND  Emerging and Developing Asia
# 3   India          IND  Emerging and Developing Asia
# 4   India          IND  Emerging and Developing Asia
#
#                                   Element  \
# 0                       Remittance inflow
# 1  Gross domestic product, current prices
# 2                          Percent of GDP
# 3  Gross domestic product, current prices
# 4      Inflation, average consumer prices
#
#                                              Unit    Scale      2000  \
# 0                                       US Dollar  Million    12,883
# 1                                       US Dollar  Billion   468.396
# 2                                      Percentage    Units     2.751
# 3  Purchasing power parity; international dollars  Billion  2,211.97
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       100 non-null    object
#  1   Country Code  100 non-null    object
#  2   Region        100 non-null    object
#  3   Element       100 non-null    object
#  4   Unit          100 non-null    object
#  5   Scale         100 non-null    object
#  6   2000          81 non-null     object
#  7   2001          81 non-null     object
#  8   2002          82 non-null     object
#  9   2003          83 non-null     object
#  10  2004          83 non-null     object
#  11  2005          83 non-null     object
#  12  2006          83 non-null     object
#  13  2007          83 non-null     object
#  14  2008          83 non-null     object
#  15  2009          83 non-null     object
#  16  2010          88 non-null     object
#  17  2011          86 non-null     object
# ...

# %%
df.describe()
# Out:
#        Country Country Code                        Region  \
# count      100          100                           100
# unique      11           10                             4
# top      India          IND  Emerging and Developing Asia
# freq        10           10                            40
#
#                                        Element       Unit  Scale 2000 2001  \
# count                                      100        100    100   81   81
# unique                                       8          9      4   80   80
# top     Gross domestic product, current prices  US Dollar  Units    0    0
# freq                                        20         20     60    2    2
#
#        2002 2003  ...    2014    2015    2016   2017   2018   2019   2020  \
# count    82   83  ...      87      88      87     87     90     86     86
# unique   81   82  ...      87      88      87     86     89     85     85
# ...
